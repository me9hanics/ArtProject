# %% [markdown]
# # Network of Painters: building a dataset from paintings datasets, then creating links
#
# The aim of this project is to create a dataset of painters from datasets such as WikiArt and Art500k, combining features, extending missing data of painters with web scraping through Google and Wiki API, and then creating links between painters based on similarity of style, geographical and social interaction.
#
# Note: One long-term goal would be to create a JSON file that contains all combined hierarchically. For example, a level in the structure could be art movement, inside it are artists with some base data like birthplace, year of birth and death and other geographical data, inside it are paintings with all contained data (even better would be including eras of painters in their substructure, and inside them the paintings). Then we could use this to create a network of art movements, artists, and paintings.
#
# NEXT STEPS:<br>
# -Add "Places" for Art500k datasets (+change datasets_notebook save.csv loads)<br>
# -Add aliases for painters in Art500k datasets<br>
# -Combine the datasets on authors<br>
#
# FURTHER STEPS: <br>
# -Define connections between painters<br>
# -Create a network of painters<br>
# -Analyze the network<br>
#
# <details><summary><u> Update 11.06:</u></summary>
# <p>
# I e-mailed an art researcher that Elisa suggested, Maximilian Schich, asking about datasets for our project. He said:
#
# -we do not have a record of social interactions between artists at the corpus scale. The closest thing is: co-exhibition networks, which you may already know from the work of Fraiberger et al. (incl. Laszlo Barabasi). (http://genetics.bwh.harvard.edu/courses/Biophysics205/Papers/All_papers/Fraiberger_2018.pdf page 2) The issue there is that the network is short, circa1985 to 2020.
#
# -Hyperlink networks (I guess WikiLinks, Pageranks and such), such as those found in Wikipedia are obviously beset with all kinds of issues, even though they do recapitulate the evolution of conventional style periods pretty well (cf. the work of Doron Goldfarb et al.. incl. myself). More locally speaking, it i a core topic in art history to shed light on the social network of artists and their patrons, but this does not lend itself to quantitative analysis.
#
# -I personally have done a visualization for Max Planck, based on the social network of 5500 individuals related to the Roman Baroque (https://zuccaro.schich.info/), which did reveal another issue, which is that for painters, art historians tend to research family relationships (more cliques), while for architects they focus on business relationships (more hubs). But here you got the inverse problem that there is not much information on the paintings
#
# -There is a question/issue he raised from this: "Should we really assume social interaction influencing the styles of artists? Note that this may substantially underestimate the plasticity of the human brain/mind! It is like assuming that cellists only hang out with cellists, when we all know that grunge bands in Seatlle all did hang out together and missing a bassist. Meanwhile we do have evidence that artists such as Rubens did routinely hang out with different(!) artists, who could serve clients with different genres and if necessary styles. Bramante did build Gothic in Milan and Renaissance style in Rome at the same time. Rubens would call in Elsheimer to do miniatures, etc. And since the mid 19th century, all artists in the Western scene were essentially familiar, not only with the same corpus of classic artists and their works, but also with the contemporary production. Large art exhibitions in Paris literally drew millions of people each year in the mid 19th century (think Burning Man or SXSW today). So it is save to say that most artists of note were familiar with a great number of styles. Styles may bifurcate. for artists the opposite may be true (cf. run DMC meets Aerosmith => https://www.youtube.com/watch?v=4B_UYYPb-Gk). If I were you, I'd turn the question around, pointing into the opposite direction: **If two artists have similar style, can we find traces that they (eventually) knew each other**?" He said influence is B.S. (literally) and there's 100 times more evidence for similarity than influence between two artworks, and suggested answering "does style lead to social interaction?"
#
# -"Here is how this question can be attacked with the available data: The standard "corpus" for artists is their "catalog raisonne", i.e. the catalog of all their works, which does not exist for all artists and is typically a lot of work, sold in expensive books. We are a long way from a comprehensive dataset like this. Yet, for the purpose of a more limited project, you could use general conventional style similarity from the usual suspect databases (Wikiart, Art500k, etc.). As a proxy of social interaction, you could use the hyperlink and/or wikidata links connected to the same artists. Even though these two sources are limited, you could still compare the two graphs as in "Wikipedia connection" vs. "visual similarity".
#
# We have recently published a paper on general similarity using compression ensembles, using a subset of art500k/Wikiart, which is essentially 65k paintings with a reliably year as a data. We have also used the first 100 days of the hic et nunc NFT art platform (which coincidentally you get both social interaction and painting information). See "Availability of data and materials" in https://epjdatascience.springeropen.com/articles/10.1140/epjds/s13688-023-00397-3#Sec21 "
#
# So this could be interesting to think about
# </p>
# </details>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Complete dataset (Combination of WikiArt and Art500k)

# %% [markdown]
# The data preparation is done in the GitHub repository [PainterPalette](https://github.com/me9hanics/PainterPalette). The final dataset is available as "artists.csv".

# %%
artists = pd.read_csv('https://raw.githubusercontent.com/me9hanics/PainterPalette/main/datasets/artists.csv')
artists
# Out:
#                   artist     Nationality          birth_place  birth_year  \
# 0           Ad Reinhardt        American              Buffalo      1913.0
# 1            Adnan Coker         Turkish                  NaN         NaN
# 2     Akkitham Narayanan          Indian               Kerala      1939.0
# 3       Alberto Magnelli  Italian,French             Florence      1888.0
# 4     Alekos Kontopoulos           Greek                Lamia      1904.0
# ...                  ...             ...                  ...         ...
# 2661     Gohar Fermanyan        Armenian                  NaN         NaN
# 2662      JAROSLAV KELUC           Czech                  NaN         NaN
# 2663             Ding Yi             NaN  Suixi County, Anhui       150.0
# 2664             Phase 2             NaN                  NaN         NaN
# 2665           TRACY 168        American        New York City      1958.0
#
#                                                  styles  \
# 0     Abstract Art, Abstract Expressionism, Color Fi...
# 1                  Abstract Art, Abstract Expressionism
# 2                                          Abstract Art
# 3     Abstract Art, Art Nouveau (Modern), Cubism, Ex...
# 4     Abstract Art, Cubism, Expressionism, Post-Impr...
# ...                                                 ...
# 2661                                 Post-Impressionism
# 2662                                      Impressionism
# 2663                                         Maximalism
# 2664                                         Street art
# 2665                                         Street art
#
#                                         styles_extended  \
# 0     {Abstract Art:15},{Abstract Expressionism:5},{...
# 1          {Abstract Art:25},{Abstract Expressionism:3}
# 2                                     {Abstract Art:17}
# 3     {Abstract Art:19},{Art Nouveau (Modern):2},{Cu...
# 4     {Abstract Art:26},{Cubism:5},{Expressionism:10...
# ...                                                 ...
# 2661                             {Post-Impressionism:3}
# 2662                                 {Impressionism:33}
# 2663                                    {Maximalism:29}
# 2664                                    {Street art:13}
# 2665                                    {Street art:11}
#
#                                             StylesYears  \
# 0     Expressionism:1944-1946,Abstract Art:1937-1941...
# 1     Abstract Art:1992-2008,Abstract Expressionism:...
# 2                                Abstract Art:1974-1974
# 3     Abstract Art:1916-1971,Cubism:1914-1935,Metaph...
# 4     Post-Impressionism:1932-1955,Expressionism:193...
# ...                                                 ...
# 2661                                                NaN
# 2662                            Impressionism:1949-1979
# 2663                                                NaN
# 2664                                                NaN
# 2665                                                NaN
#
#                                             StylesCount  \
# 0     {Expressionism:7}, {Abstract Art:15}, {Color F...
# 1         {Abstract Art:25}, {Abstract Expressionism:3}
# 2                                     {Abstract Art:17}
# 3     {Abstract Art:21}, {Cubism:10}, {Metaphysical ...
# 4     {Post-Impressionism:8}, {Expressionism:11}, {R...
# ...                                                 ...
# 2661                             {Post-Impressionism:3}
# 2662                                 {Impressionism:33}
# 2663                                                NaN
# 2664                                                NaN
# 2665                                                NaN
#
#                                             PlacesCount Contemporary  ...  \
# 0     {New York City:29},{NY:31},{US:32},{Buffalo:2}...           No  ...
# 1                                                   NaN          Yes  ...
# 2                                                   NaN           No  ...
# 3                                                   NaN           No  ...
# 4                                                   NaN           No  ...
# ...                                                 ...          ...  ...
# 2661                                                NaN          NaN  ...
# 2662                                                NaN           No  ...
# 2663                                                NaN          NaN  ...
# 2664                     {New York:1},{United States:1}          NaN  ...
# 2665                                       {New York:1}          NaN  ...
#
#      FirstYear LastYear                                             Places  \
# 0       1937.0   1966.0  US, NY, Canberra, Fort Worth, Buffalo, Austral...
# 1       1968.0   2008.0                                                NaN
# 2       1974.0   1974.0                                                NaN
# 3       1909.0   1971.0                                                NaN
# 4       1931.0   1974.0                                                NaN
# ...        ...      ...                                                ...
# 2661       NaN      NaN                                                NaN
# 2662    1949.0   1979.0                                                NaN
# 2663    1989.0   1991.0                                                NaN
# 2664       NaN      NaN                            New York, United States
# 2665    1987.0   1987.0                                           New York
#
#                                             PlacesYears  \
# 0     New York City:1938-1966,NY:1938-1966,US:1938-1...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2661                                                NaN
# 2662                                                NaN
# 2663                                                NaN
# 2664                                                NaN
# 2665                                 New York:1987-1987
#
#                                          PaintingSchool  \
# 0     New York School,American Abstract Artists,Iras...
# 1                                                   NaN
# 2                                                   NaN
# 3                                  Abstraction-Création
# 4                                                   NaN
# ...                                                 ...
# 2661                                                NaN
# 2662                                                NaN
# 2663                                                NaN
# 2664                                                NaN
# 2665                                                NaN
#
#                                       Influencedby  \
# 0     Piet Mondrian,Kazimir Malevich,Josef Albers,
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 2661                                           NaN
# 2662                                           NaN
# 2663                                           NaN
# 2664                                           NaN
# 2665                                           NaN
#
#                                            Influencedon Pupils Teachers  \
# 0     Donald Judd,Barnett Newman,Mark Rothko,Frank S...    NaN      NaN
# 1                                                   NaN    NaN      NaN
# 2                                                   NaN    NaN      NaN
# 3                                                   NaN    NaN      NaN
# 4                                                   NaN    NaN      NaN
# ...                                                 ...    ...      ...
# 2661                                                NaN    NaN      NaN
# 2662                                                NaN    NaN      NaN
# 2663                                                NaN    NaN      NaN
# 2664                                                NaN    NaN      NaN
# 2665                                                NaN    NaN      NaN
#
#      FriendsandCoworkers
# 0       Jackson Pollock,
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 2661                 NaN
# 2662                 NaN
# 2663                 NaN
# 2664                 NaN
# 2665                 NaN
#
# [2666 rows x 24 columns]

# %% [markdown]
# ## Other: WikiArt data

# %% [markdown]
# Load the cleaned paintings data

# %%
wa_paintings = pd.read_csv('https://raw.githubusercontent.com/me9hanics/PainterPalette/main/datasets/wikiart_paintings_refined.csv') 
print("Length:", len(wa_paintings))
wa_paintings.head() #Consider dropping style: "Unknown"
# Out:
# Length: 175313
#           artist                           style               genre  \
# 0  Andrei Rublev  Moscow school of icon painting  religious painting
# 1  Andrei Rublev  Moscow school of icon painting  religious painting
# 2  Andrei Rublev  Moscow school of icon painting           miniature
# 3  Andrei Rublev  Moscow school of icon painting  religious painting
# 4  Andrei Rublev  Moscow school of icon painting           miniature
#
#         movement                                               tags
# 0  Byzantine Art  ['Christianity', 'saints-and-apostles', 'angel...
# 1  Byzantine Art  ['Christianity', 'Old-Testament', 'Daniel', 'p...
# 2  Byzantine Art  ['Christianity', 'saints-and-apostles', 'Khitr...
# 3  Byzantine Art  ['Christianity', 'saints-and-apostles', 'St.-L...
# 4  Byzantine Art  ['Christianity', 'arts-and-crafts', 'saints-an...

# %% [markdown]
# Load the grouped data: artists grouped by style

# %%
wa_grouped = pd.read_csv('https://raw.githubusercontent.com/me9hanics/PainterPalette/main/datasets/wikiart_artists_styles_grouped.csv')
print("Length:", len(wa_grouped), "\n", "Number of groups with only 1 count:", len(wa_grouped[wa_grouped['count']==min(wa_grouped['count'])]))
wa_grouped[wa_grouped['artist'].str.contains("Monet")].sort_values(by=['count'], ascending=False)
# Out:
# Length: 7646
#  Number of groups with only 1 count: 1115
#               style        artist       movement  count
# 2963  Impressionism  Claude Monet  Impressionism   1341
# 5468        Realism  Claude Monet  Impressionism     12
# 7041        Unknown  Claude Monet  Impressionism     12
# 462     Academicism  Claude Monet  Impressionism      1
# 3339       Japonism  Claude Monet  Impressionism      1

# %% [markdown]
# ### Birthplaces, birth years

# %%
artists_A = pd.read_csv('https://raw.githubusercontent.com/me9hanics/PainterPalette/main/datasets/wikiart_artists.csv')
artists_A
# Out:
#                   artist                                             styles  \
# 0           Ad Reinhardt  Abstract Art, Abstract Expressionism, Color Fi...
# 1            Adnan Coker               Abstract Art, Abstract Expressionism
# 2     Akkitham Narayanan                                       Abstract Art
# 3       Alberto Magnelli  Abstract Art, Art Nouveau (Modern), Cubism, Ex...
# 4     Alekos Kontopoulos  Abstract Art, Cubism, Expressionism, Post-Impr...
# ...                  ...                                                ...
# 3198    Serhij Schyschko                                            Unknown
# 3199     Vudon Baklytsky                                            Unknown
# 3200   Wolfgang Tillmans                                            Unknown
# 3201            Wu Daozi                                            Unknown
# 3202        Olowe of Ise                                             Yoruba
#
#                       movement  \
# 0       Abstract Expressionism
# 1                 Abstract Art
# 2                 Abstract Art
# 3                 Abstract Art
# 4               Social Realism
# ...                        ...
# 3198              Academic Art
# 3199  Soviet Nonconformist Art
# 3200              Contemporary
# 3201    Tang Dynasty (618–907)
# 3202                Native Art
#
#                                         styles_extended  pictures_count  \
# 0     {Abstract Art:15},{Abstract Expressionism:5},{...              52
# 1          {Abstract Art:25},{Abstract Expressionism:3}              28
# 2                                     {Abstract Art:17}              17
# 3     {Abstract Art:19},{Art Nouveau (Modern):2},{Cu...              35
# 4     {Abstract Art:26},{Cubism:5},{Expressionism:10...              79
# ...                                                 ...             ...
# 3198                                        {Unknown:9}               9
# 3199                                       {Unknown:46}              46
# 3200                                        {Unknown:9}               9
# 3201                                        {Unknown:8}               8
# 3202                                        {Yoruba:13}              13
#
#      birth_place  birth_year
# 0        Buffalo      1913.0
# 1            NaN         NaN
# 2         Kerala      1939.0
# 3       Florence      1888.0
# 4          Lamia      1904.0
# ...          ...         ...
# 3198         NaN         NaN
# 3199         NaN         NaN
# 3200   Remscheid      1968.0
# 3201    Chang'an       680.0
# 3202         NaN         NaN
#
# [3203 rows x 7 columns]

# %% [markdown]
# ## Art500K

# %% [markdown]
# First dataset (from official website)

# %%
art500k = pd.read_csv('https://raw.githubusercontent.com/me9hanics/PainterPalette/main/datasets/art500k_paintings_cleaned.csv')
(art500k[0:10])
# Out:
#        author_name Genre Style Nationality PaintingSchool ArtMovement  \
# 0  Gustave Courbet   NaN   NaN         NaN            NaN         NaN
# 1    Auguste Rodin   NaN   NaN         NaN            NaN         NaN
# 2      Frida Kahlo   NaN   NaN         NaN            NaN         NaN
# 3           Banksy   NaN   NaN         NaN            NaN         NaN
# 4         El Greco   NaN   NaN         NaN            NaN         NaN
# 5         El Greco   NaN   NaN         NaN            NaN         NaN
# 6     Diego Rivera   NaN   NaN         NaN            NaN         NaN
# 7     Claude Monet   NaN   NaN         NaN            NaN         NaN
# 8   Francisco Goya   NaN   NaN         NaN            NaN         NaN
# 9   Francisco Goya   NaN   NaN         NaN            NaN         NaN
#
#             Date Influencedby Influencedon  Tag Pupils  \
# 0            NaN          NaN          NaN  NaN    NaN
# 1            NaN          NaN          NaN  NaN    NaN
# 2            NaN          NaN          NaN  NaN    NaN
# 3            NaN          NaN          NaN  NaN    NaN
# 4  ca. 1610-1614          NaN          NaN  NaN    NaN
# 5            NaN          NaN          NaN  NaN    NaN
# 6            NaN          NaN          NaN  NaN    NaN
# 7            NaN          NaN          NaN  NaN    NaN
# 8            NaN          NaN          NaN  NaN    NaN
# 9            NaN          NaN          NaN  NaN    NaN
#
#                                           Location Teachers  \
# 0                                              NaN      NaN
# 1                                              NaN      NaN
# 2                                              NaN      NaN
# 3  in a settlement in Palestine in the middle east      NaN
# 4                                              NaN      NaN
# 5                                              NaN      NaN
# 6                                              NaN      NaN
# 7                                              NaN      NaN
# 8                                              NaN      NaN
# 9                                              NaN      NaN
#
#   FriendsandCoworkers
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN

# %%
art500k_artists = pd.read_csv('https://raw.githubusercontent.com/me9hanics/PainterPalette/main/datasets/art500k_artists.csv')
art500k_artists[0:7]
# Out:
#             artist    Nationality                      PaintingSchool  \
# 0  Gustave Courbet         French                                 NaN
# 1    Auguste Rodin         French                                 NaN
# 2      Frida Kahlo        Mexican                                 NaN
# 3           Banksy            NaN                                 NaN
# 4         El Greco  Spanish,Greek                       Cretan School
# 5     Diego Rivera        Mexican  Mexican Mural Renaissance,La Ruche
# 6     Claude Monet         French                                 NaN
#
#                                          ArtMovement  \
# 0                                      {Realism:272}
# 1                  {Modern art:3},{Impressionism:91}
# 2            {Naïve Art (Primitivism),Surrealism:99}
# 3                                                NaN
# 4  {Spanish Renaissance:1},{Renaissance:2},{Manne...
# 5                      {Social Realism,Muralism:146}
# 6                {Modern art:3},{Impressionism:1340}
#
#                                         Influencedby  \
# 0  Rembrandt,Caravaggio,Diego Velazquez,Peter Pau...
# 1                            Michelangelo,Donatello,
# 2  Amedeo Modigliani,Diego Rivera,Jose Clemente O...
# 3                                                NaN
# 4                                     Byzantine Art,
# 5                      Marc Chagall,Robert Delaunay,
# 6  Gustave Courbet,Charles-Francois Daubigny,John...
#
#                                         Influencedon                Pupils  \
# 0  Edouard Manet,Claude Monet,Pierre-Auguste Reno...                   NaN
# 1  Georgia O'Keeffe,Man Ray,Aristide Maillol,Olex...  Constantin Brancusi,
# 2        Judy Chicago,Georgia O'Keeffe,Feminist Art,                   NaN
# 3                                                NaN                   NaN
# 4  Expressionism,Cubism,Eugene Delacroix,Edouard ...                   NaN
# 5                   Frida Kahlo,Pedro Coronel,Vlady,                   NaN
# 6  Childe Hassam,Robert Delaunay,Wassily Kandinsk...                   NaN
#
#                         Teachers  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                        Titian,
# 5                            NaN
# 6  Eugene Boudin,Charles Gleyre,
#
#                                  FriendsandCoworkers  FirstYear  LastYear  \
# 0                                                NaN     1830.0    1877.0
# 1                                                NaN     1865.0    1985.0
# 2                                                NaN     1922.0    1954.0
# 3                                                NaN     2011.0    2011.0
# 4                                     Giulio Clovio,     1568.0    1614.0
# 5  Amedeo Modigliani,Saturnino Herran,Roberto Mon...     1904.0    1956.0
# 6  Alfred Sisley,Pierre-Auguste Renoir,Camille Pi...     1858.0    1926.0
#
#                                               Places  \
# 0  London, Montpellier, Moscow, CA, UK, Norway, D...
# 1  London, CA, UK, Switzerland, Lisbon, US, Germa...
# 2  CA, LA, New York, US, New Orleans, Washington ...
# 3  Los Angeles, London, UK, Palestine, California...
# 4  Seville, London, Illescas, Romania, Moscow, Gr...
# 5  Moscow, CA, Acapulco, New York, Spain, Northam...
# 6  London, Main, Moscow, Rotterdam, Giverny, CA, ...
#
#                                          PlacesYears  \
# 0  France:1841-1876,Switzerland:1844-1874,Lille:1...
# 1  France:1865-1889,Paris:1865-1898,CA:1891-1891,...
# 2  Mexico:1927-1954,San Francisco:1931-1933,Mexic...
# 3                      London:2011-2011,UK:2011-2011
# 4  Spain:1577-1599,London:1600-1600,UK:1600-1600,...
# 5  Acapulco:1956-1956,Mexico:1905-1956,Guerrero:1...
# 6  France:1861-1924,London:1869-1889,UK:1869-1908...
#
#                                          StylesYears  \
# 0            Realism:1835-1877,Romanticism:1830-1849
# 1                            Impressionism:1865-1905
# 2  Naïve Art (Primitivism):1922-1954,Surrealism:1...
# 3                                                NaN
# 4             Mannerism (Late Renaissance):1568-1600
# 5  Cubism:1912-1916,Muralism:1922-1956,Art Deco:1...
# 6  Impressionist:1879-1904,Impressionism:1864-192...
#
#                                          StylesCount  \
# 0                    {Realism:257}, {Romanticism:13}
# 1                                 {Impressionism:90}
# 2      {Naïve Art (Primitivism):99}, {Surrealism:15}
# 3                                                NaN
# 4  {Renaissance:2}, {XVI CenturySpanish Painting:...
# 5  {Post-impressionism:1}, {Cubism:19}, {Mexican ...
# 6  {Nineteenth-Century European PaintingImpressio...
#
#                                          PlacesCount Contemporary  \
# 0  {France:88},{Switzerland:7},{Lille:8},{Paris:4...           No
# 1  {France:52},{Paris:15},{Brussels:2},{Belgium:1...          NaN
# 2  {Mexico:50},{San Francisco:6},{New York:4},{Me...           No
# 3  {Palestine:1},{Los Angeles:3},{California:3},{...          Yes
# 4  {Spain:75},{Boston:1},{MA:1},{US:27},{Museo de...           No
# 5  {France:1},{Paris:1},{Moscow:1},{Acapulco:2},{...           No
# 6  {France:79},{Giverny:1},{London:6},{UK:15},{Bo...           No
#
#                  Type
# 0  Painting/Sculpture
# 1  Painting/Sculpture
# 2  Painting/Sculpture
# 3  Painting/Sculpture
# 4  Painting/Sculpture
# 5  Painting/Sculpture
# 6  Painting/Sculpture

# %% [markdown]
# ## Creating networks
#
# This is found in the networks folder, mostly in the networks.ipynb notebook.<br>
# Some work can be found in the *scipy.ipynb* notebook.<br>
